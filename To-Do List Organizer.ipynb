# %% [markdown]
# Introduction:
#
# Embark on a journey to enhance your Python skills with an application that simplifies monitoring and analyzing your daily expenses. This project, ideal for those familiar with Python basics, introduces key concepts like handling user inputs, performing arithmetic operations, and mastering basic file handling. It's not just about coding; it's about creating a tool that brings practical value to your everyday life.
#
# Objective:
#
# The goal is to create a user-friendly application that efficiently tracks daily expenses and offers insightful summaries of spending patterns.
#
# Features:
#
# Add Expense: The application prompts users to input the date, expense category (such as food, transport, or utilities), and the amount spent. This feature is fundamental for recording daily expenditures.
#
# View Expenses: Users can view their expenses filtered by a specific day, week, or month. This flexibility allows for a tailored review of spending habits.
#
# Expense Summary: This feature provides a comprehensive summary, categorizing and totaling expenses by each category. It's an excellent tool for gaining a clearer understanding of spending distribution.
#
# Data Storage: The application ensures data persistence across sessions by saving expense records to a file. This approach makes it easy to maintain and track financial data over time.
#
# Concepts to Learn:
#
# Variables and Data Types: Learn to utilize various data types to store critical information like dates, categories, and amounts.
#
# Control Structures: Implement loops and conditional statements to navigate the application's menu, process user inputs, and ensure data validation.
#
# Functions: Develop modular code by creating specific functions for adding, viewing, and summarizing expenses. This approach enhances code readability and maintainability.
#
# File Handling: Gain practical experience in reading from and writing to text or CSV files, a crucial skill for data persistence in applications.
#
# This project is not only about coding; it's an exercise in creating a practical, everyday tool while reinforcing your Python skills. It's ideal for those looking to apply their programming knowledge in real-world scenarios.

# %%
# To-Do List Organizer

def display_tasks():
    with open('todo_list.txt', 'r') as file:
        tasks = file.readlines()
        print("\nYour To-Do List:")
        for i, task in enumerate(tasks, 1):
            print(f"{i}. {task.strip()}")

def add_task():
    task = input("Enter the task you want to add: ")
    with open('todo_list.txt', 'a') as file:
        file.write(task + "\n")
    print("Task added successfully!")

def update_task():
    display_tasks()
    task_number = int(input("Enter the task number you want to update: "))
    updated_task = input("Enter the updated task: ")
    with open('todo_list.txt', 'r+') as file:
        tasks = file.readlines()
        tasks[task_number - 1] = updated_task + "\n"
        file.seek(0)
        file.writelines(tasks)
    print("Task updated successfully!")

def delete_task():
    display_tasks()
    task_number = int(input("Enter the task number you want to delete: "))
    with open('todo_list.txt', 'r+') as file:
        tasks = file.readlines()
        del tasks[task_number - 1]
        file.seek(0)
        file.truncate()
        file.writelines(tasks)
    print("Task deleted successfully!")

def main():
    while True:
        print("\nTo-Do List Organizer")
        print("1. Display Tasks")
        print("2. Add Task")
        print("3. Update Task")
        print("4. Delete Task")
        print("5. Exit")

        choice = input("Enter your choice: ")

        if choice == '1':
            display_tasks()
        elif choice == '2':
            add_task()
        elif choice == '3':
            update_task()
        elif choice == '4':
            delete_task()
        elif choice == '5':
            print("Exiting To-Do List Organizer. Have a great day!")
            break
        else:
            print("Invalid choice. Please choose a valid option.")

if __name__ == "__main__":
    main()
# Out:
# To-Do List Organizer
# 1. Display Tasks
# 2. Add Task
# 3. Update Task
# 4. Delete Task
# 5. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-11b806127758> in <cell line: 63>()
#      62
#      63 if __name__ == "__main__":
# ---> 64     main()
#
# <ipython-input-1-11b806127758> in main()
#      45         print("5. Exit")
#      46
# ---> 47         choice = input("Enter your choice: ")
#      48
#      49         if choice == '1':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...
