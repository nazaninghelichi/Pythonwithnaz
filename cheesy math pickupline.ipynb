# %%
import random

# List of jokes
jokes = [
    "Are you a 90-degree angle? Because you’re looking right.", "Are you a square? Because you've got all the right angles.", "Our friendship is like dividing by zero, it's undefined.", "Are you the square root of -1? Because you can’t be real.", "If I were a math problem, would you solve me?", "You must be the square root of two because I feel irrational around you.", "If you were a triangle, you’d be acute one.", "We’re like parallel lines, always close but never touching.", "Are you a math book? Because you’ve got a lot of problems, but you’re still interesting.", "You’re like a perfect number, not just divisible, but perfectly complete.", "If I could rearrange the alphabet, I’d put U and I together like coefficients.", "Do you like math? Because I think we add up nicely.", "Are you an angle? Because you’re so acute.", "Our friendship is like pi, natural, irrational, and very important.", "You must be a geometry book, because you've got a lot of fine points.", "We’re like complementary angles, always adding up to something great.", "Are you a graph? Because I'm finding my interest in you increasing.", "You’re like an algebra equation, easy to understand but full of interesting surprises.", "If you were a math test, you’d be unreasonably difficult, but worth all the effort.", "You must be a circle, because you're perfectly rounded."
]

# Randomly select a joke
selected_joke = random.choice(jokes)

# Display the joke
print(selected_joke)
# Out:
# If you were a math test, you’d be unreasonably difficult, but worth all the effort.
